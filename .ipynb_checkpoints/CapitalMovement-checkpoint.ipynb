# %%
# Влияние вывоза капитала на экономику принимающей страны.

# %%
# The impact of the export of capital on the economy of the host country.

# %%
# https://eprints.soas.ac.uk/22537/1/Banaji_Grossman_excerpt.pdf

# %%
# https://www.investopedia.com/terms/c/capital-outflow.asp#:~:text=Capital%20outflow%20is%20the%20movement,of%20political%20or%20economic%20instability.

# %%
# https://webarchiv.ethz.ch/vwl/down/folien/Principles_Macro_08/Lecture09.pdf

# %%
"""

Capital outflow is the movement of assets out of a country. 
Capital outflow is considered undesirable as it is often the 
result of political or economic instability. The flight of assets
occurs when foreign and domestic investors sell off their holdings 
in a particular country because of perceived weakness in the nation's 
economy and the belief that better opportunities exist abroad.

"""

# %%
"""

BOP = Current Account + Financial Account + Capital Account + Balancing item

"""

# %%
# if the supply of loanable funds increases => fed prints more money => 
# the fed buys treasury notes => gives the us gov free $ 
#

# %%
# Money Market Chart

# %%
# Interest Rates and Ruble Exchange Rate

# %%
# theory: as interest rates go up => ruble increases in value => negative correlation

# %%
# scrape data from CBRF 
# https://www.cbr.ru/statistics/avgprocstav/?UniDbQuery.Posted=True&UniDbQuery.From=3.07.2009&UniDbQuery.To=1.03.2022

# %%
# !pip3 install selenium

# %%
import pandas as pd

import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
import pandas as pd
import yfinance as yf
import yahoofinancials
import seaborn as sns
import datetime
from datetime import date
import matplotlib.pyplot as plt

from scipy.ndimage.interpolation import zoom
import numpy as np

import requests
import urllib.request
import time
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# get USD/RUB historical data
yf.pdr_override() 
df = pdr.get_data_yahoo("USDRUB=X", start="2009-07-01", end="2022-04-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#yield curve CBRF now
url = 'https://www.cbr.ru/statistics/avgprocstav/?UniDbQuery.Posted=True&UniDbQuery.From=3.07.2009&UniDbQuery.To=1.03.2022'   

# Connect to the URL
response = requests.get(url)

# Parse HTML and save to BeautifulSoup object¶
soup = BeautifulSoup(response.text, "html.parser")
raw = soup.findAll('td',{"class":""})

index = []
vals = []

# %%
# separate index from vals in soup
def separate(raw):
    for i in range(len(raw)):
        if i % 2 == 0:
            index.append(raw[i].decode_contents())
        else:
            vals.append(raw[i].decode_contents())

# %%
separate(raw)

# %%
# remove comma from string and convert to float
rates = []

def removeComma(x):
    for i in range(len(vals)):
        y = float(vals[i].replace(',', "."))
        rates.append(y)

# %%
removeComma(vals)

# %%
# reversing data 
index=index[::-1]
rates=rates[::-1]

# %%
df1 = pd.DataFrame({'index': index, 'rates': rates})

# %%
# original array:
x = df1["rates"]

# set resample ratio:
resample_ratio = len(df) / len(x)

# resample array:
y = zoom(x, resample_ratio, order=0)

# %%
# sanity check
print(len(y))
print(len(df))
# Out:
# 3314
# 3314

# %%
df1 = pd.DataFrame({'rates': y})

# %%
df1["rates"].plot()
# Out:
# <AxesSubplot:>

# %%
# drop outlier and plot
df.at["2016-01-06","Close"] = 74
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Rates'] = df1['rates'].values

# %%
df = df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1)

# %%
df
# Out:
#                 Close   Rates
# Date
# 2009-06-30  31.073999  14.840
# 2009-07-01  31.096300  14.840
# 2009-07-02  31.129000  14.840
# 2009-07-03  31.162001  14.840
# 2009-07-06  31.349001  14.840
# ...               ...     ...
# 2022-04-07  82.089996   8.587
# 2022-04-08  79.214996  20.510
# 2022-04-11  85.089996  20.510
# 2022-04-12  83.464996  20.510
# 2022-04-13  85.339996  20.510
#
# [3314 rows x 2 columns]

# %%
def plot_data(data_df, normalize,log_plot):
    data_df = data_df.dropna()
    
    # normalize df
    if normalize == True:
        data_df = (data_df - data_df.mean()) / data_df.std()
    else:
        pass

    for column in data_df:

        ax = data_df[column].plot(figsize=(14, 10), legend=True, logy=log_plot, grid=True)

    ax.get_legend().set_bbox_to_anchor((1.3, 1))

    #return data_df

# %%
normalize = True
log_plot = False

plot_data(df, normalize, log_plot)

# %%
# calculate correlation without shift
sum_corr = df.corr().sum().sort_values(ascending=True).index.values
df[sum_corr].corr()
# Out:
#           Close     Rates
# Close  1.000000 -0.474907
# Rates -0.474907  1.000000

# %%
df
# Out:
#                 Close   Rates
# Date
# 2009-06-30  31.073999  14.840
# 2009-07-01  31.096300  14.840
# 2009-07-02  31.129000  14.840
# 2009-07-03  31.162001  14.840
# 2009-07-06  31.349001  14.840
# ...               ...     ...
# 2022-04-07  82.089996   8.587
# 2022-04-08  79.214996  20.510
# 2022-04-11  85.089996  20.510
# 2022-04-12  83.464996  20.510
# 2022-04-13  85.339996  20.510
#
# [3314 rows x 2 columns]

# %%
ax = df.plot.scatter(x='Rates', y='Close', c=df.index, cmap='viridis', figsize=(14,10))

ax.set_xlabel('Rates', fontsize=15)
ax.set_ylabel("RUB", fontsize=15)
ax.set_title('CBRF Interest Rate & USD/RUB Exchange Rate (30.09.09 - 13.04.2022)')

ax.grid(True)

plt.savefig("correlation.png")

# %%
# calculate correlation without shift
sum_corr = df.corr().sum().sort_values(ascending=True).index.values
df[sum_corr].corr()
# Out:
#           Close     Rates
# Close  1.000000 -0.474907
# Rates -0.474907  1.000000

# %%
# Let's take a closer look at the correlation from 2017 - 2021

# %%
df.describe()
# Out:
#              Close        Rates
# count  3314.000000  3314.000000
# mean     51.777005     8.475647
# std      18.488422     2.335464
# min      27.154900     4.326000
# 25%      31.414075     7.135000
# 50%      57.740850     8.400000
# 75%      65.950777     9.650000
# max     138.965103    20.510000

# %%
df = df.iloc[2000:3000]

# %%
df
# Out:
#                 Close  Rates
# Date
# 2017-03-28  56.878399  8.045
# 2017-03-29  56.967899  8.045
# 2017-03-30  56.651299  8.045
# 2017-03-31  55.984299  8.045
# 2017-04-03  56.234600  8.045
# ...               ...    ...
# 2021-01-22  73.947701  4.486
# 2021-01-25  75.314903  4.486
# 2021-01-26  75.282204  4.486
# 2021-01-27  75.070099  4.486
# 2021-01-28  75.873398  4.486
#
# [1000 rows x 2 columns]

# %%
ax = df.plot.scatter(x='Rates', y='Close', c=df.index, cmap='viridis', figsize=(14,10))

ax.set_xlabel('Rates', fontsize=15)
ax.set_ylabel("RUB", fontsize=15)
ax.set_title('CBRF Interest Rate & USD/RUB Exchange Rate (28.03.17 - 28.01.2021)')

ax.grid(True)

plt.savefig("correlation.png")

# %%
# calculate correlation without shift
sum_corr = df.corr().sum().sort_values(ascending=True).index.values
df[sum_corr].corr()
# Out:
#           Close     Rates
# Close  1.000000 -0.816879
# Rates -0.816879  1.000000

# %%
normalize = True
log_plot = False

plot_data(df, normalize, log_plot)

# %%
# correlation to Captital outflow (BOP) to other indicators such as interest rates & exchange rates
# https://www.cbr.ru/vfs/eng/statistics/credit_statistics/direct_investment/21e-dir_inv.xlsx

# %%
# Hypothesis: it will be a positive correlation in regards to rate of change 

# when USD/RUB % change == +  =>  capital inflow is + 


# Yes, as the exchange rate goes up, it becomes more expensive for investors to buy 
# rubles, however, as the exchange rate goes up, so does confidence in the 
# russian economy. 


# logically however, the correlation would be inverse because, investors get a good 
# deal on Russian assets when the Ruble is weaker to the dollar.

# %%
import requests
import pandas as pd
url = 'https://www.cbr.ru/vfs/eng/statistics/credit_statistics/direct_investment/21e-dir_inv.xlsx'
r = requests.get(url)
open('dir_inv.xls', 'wb').write(r.content)
df1 = pd.read_excel('dir_inv.xls')

# %%
df1
# Out:
#    Direct Investment of the Russian Federation by Institutional Sector           \
# 0                 (Balance of Payments Transactions)
# 1                            (millions of US dollars)
# 2                                                 NaN
# 3                                                 NaN
# 4                                   Direct investment
# 5                                              Abroad
# 6                                 General government
# 7                                      Equity capital
# 8                                               Banks
# 9                                      Equity capital
# 10                           Reinvestment of earnings
# 11                                   Debt instruments
# 12                                      Other sectors
# 13                                     Equity capital
# 14                                           Received
# 15                                          Withdrawn
# 16                           Reinvestment of earnings
# 17                                   Debt instruments
# 18                                           Received
# 19                                             Repaid
# 20                                          In Russia
# 21                                              Banks
# 22                                     Equity capital
# 23                           Reinvestment of earnings
# 24                                   Debt instruments
# 25                                      Other sectors
# 26                                     Equity capital
# 27                                           Received
# 28                                          Withdrawn
# 29                           Reinvestment of earnings
# 30                                   Debt instruments
# 31                                           Received
# 32                                             Repaid
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                              Note:
# 38  1. Transactions balance signs: "+" denotes inc...
# 39  2. Transactions balance signs in the row "Dire...
# 40                                                NaN
# 41                            Updated on 8 April 2022
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3     Q1 1994    Q2 1994    Q3 1994    Q4 1994       1994    Q1 1995
# 4   -66.95455   -50.6787   -51.5994  -209.3712 -378.60385  -69.52675
# 5     74.9835   72.27325     72.214     91.499  310.96975   129.5546
# 6           0          0          0          0          0          -
# 7           0          0          0          0          0          -
# 8      1.6735    1.96325      0.904     14.189   18.72975     1.5546
# 9      1.6735    1.96325      0.904     14.189   18.72975     1.5546
# 10          0          0          0          0          0          -
# 11          -          -          -          -          -          -
# 12      73.31      70.31      71.31      77.31     292.24        128
# 13          0          0          0          0          0          -
# 14          0          0          0          0          0          -
# 15          0          0          0          0          0          -
# 16          0          0          0          0          0          -
# 17          0          0          0          0          0          -
# 18          0          0          0          0          0          -
# 19          0          0          0          0          0          -
# 20  141.93805  122.95195   123.8134   300.8702   689.5736  199.08135
# 21    7.45805   -1.42805    17.3334    32.2902    55.6536  -25.69865
# 22    7.45805   -1.42805    17.3334    32.2902    55.6536  -25.69865
# 23          0          0          0          0          0          -
# 24          0          0          0          0          0          -
# 25     134.48     124.38     106.48     268.58     633.92     224.78
# 26          0          0          0          0          0          -
# 27          0          0          0          0          0          -
# 28          0          0          0          0          0          -
# 29          0          0          0          0          0          -
# 30          0          0          0          0          0          -
# 31          0          0          0          0          0          -
# 32          0          0          0          0          0          -
# 33        NaN        NaN        NaN        NaN        NaN        NaN
# 34        NaN        NaN        NaN        NaN        NaN        NaN
# 35        NaN        NaN        NaN        NaN        NaN        NaN
# 36        NaN        NaN        NaN        NaN        NaN        NaN
# 37        NaN        NaN        NaN        NaN        NaN        NaN
# 38        NaN        NaN        NaN        NaN        NaN        NaN
# 39        NaN        NaN        NaN        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN
# 41        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  Unnamed: 131  Unnamed: 132  \
# 0         NaN        NaN        NaN  ...           NaN           NaN
# 1         NaN        NaN        NaN  ...           NaN           NaN
# 2         NaN        NaN        NaN  ...           NaN           NaN
# 3     Q2 1995    Q3 1995    Q4 1995  ...       Q1 2020       Q2 2020
# 4   -113.6062 -456.94645  -819.8606  ...    4377.27375  -1618.091527
# 5    186.3214  184.48605   105.4214  ...    617.796134   4638.900254
# 6           -          -          -  ...             0             0
# 7           -          -          -  ...             0             0
# 8     58.3214    4.48605   -22.5786  ...    251.217927   -189.048574
# 9     58.3214    4.48605   -22.5786  ...     40.366172     15.860747
# 10          -          -          -  ...      100.9291     83.347288
# 11          -          -          -  ...    109.922655   -288.256609
# 12        128        180        128  ...    366.578207   4827.948828
# 13          -          -          -  ...       -152.03   3046.482638
# 14          -          -          -  ...     1348.6629   3475.784428
# 15          -          -          -  ...    -1500.6929    -429.30179
# 16          -          -          -  ...    863.461588   2688.381588
# 17          -          -          -  ...   -344.853381   -906.915397
# 18          -          -          -  ...  19029.088651  21632.246243
# 19          -          -          -  ... -19373.942032  -22539.16164
# 20   299.9276   641.4325    925.282  ...  -3759.477616   6256.991781
# 21     7.4476    -3.3475     16.802  ...    316.540075    390.050892
# 22     7.4476    -3.3475     16.802  ...     75.649175     45.888096
# 23          -          -          -  ...   -113.920723    668.174024
# 24          -          -          -  ...    354.811623   -324.011228
# 25     292.48     644.78     908.48  ...  -4076.017691   5866.940889
# 26          -          -          -  ...   -530.493725      1210.241
# 27          -          -          -  ...      4831.097      3396.081
# 28          -          -          -  ...  -5361.590725      -2185.84
# 29          -          -          -  ...        237.57       -322.85
# 30          -          -          -  ...  -3783.093966   4979.549889
# 31          -          -          -  ...   33399.37381  37932.836014
# 32          -          -          -  ... -37182.467775 -32953.286125
# 33        NaN        NaN        NaN  ...           NaN           NaN
# 34        NaN        NaN        NaN  ...           NaN           NaN
# 35        NaN        NaN        NaN  ...           NaN           NaN
# 36        NaN        NaN        NaN  ...           NaN           NaN
# 37        NaN        NaN        NaN  ...           NaN           NaN
# 38        NaN        NaN        NaN  ...           NaN           NaN
# 39        NaN        NaN        NaN  ...           NaN           NaN
# 40        NaN        NaN        NaN  ...           NaN           NaN
# 41        NaN        NaN        NaN  ...           NaN           NaN
#
#     Unnamed: 133  Unnamed: 134   Unnamed: 135  Unnamed: 136  Unnamed: 137  \
# 0            NaN           NaN            NaN           NaN           NaN
# 1            NaN           NaN            NaN           NaN           NaN
# 2            NaN           NaN            NaN           NaN           NaN
# 3        Q3 2020       Q4 2020    2020.000000       Q1 2021       Q2 2021
# 4   -5411.231332   -979.762267   -3631.815775     3182.8281   3288.602271
# 5    -2977.25325   3567.555126    5846.998141    9113.12065   8705.566513
# 6              0             0       0.000000             0             0
# 7              0             0       0.000000             0             0
# 8    -125.207686    245.137608     182.099275    107.470383   -199.191608
# 9     103.670916     15.991693     175.889528    -53.543969    -89.769397
# 10     90.289947     98.759564     373.325899    173.070527    260.692602
# 11   -319.168549    130.386351    -367.116152    -12.056175   -370.114813
# 12  -2852.045564   3322.417518    5664.898866   9005.650267   8904.758121
# 13     70.873716   1244.730643    4210.056997      951.5663     2216.0575
# 14   2101.888017   2931.152203    9857.487549     1175.9829     2655.6166
# 15  -2031.014302   -1686.42156   -5647.430552     -224.4166     -439.5591
# 16  -3476.442783   2500.027763    2575.428034   4823.375743   5881.302064
# 17    553.523503   -422.340889   -1120.586164   3230.708224    807.398557
# 18   24553.60913  32942.221553   98157.165577  34172.818802  26423.949997
# 19 -24000.085627 -33364.562443  -99277.751741 -30942.110578  -25616.55144
# 20   2433.978082   4547.317392    9478.813916    5930.29255   5416.964241
# 21    370.496219     400.86761    1477.954796   1574.639946  -1143.618405
# 22     54.964907    -65.597901     110.904277     16.598623   -181.138148
# 23    287.362019    205.351626    1046.966946    488.744375    567.566684
# 24     28.169293    261.113885     320.083573   1069.296948  -1530.046941
# 25   2063.481863   4146.449782    8000.859120   4355.652604   6560.582646
# 26       3283.01       3361.44    7324.197275    103.817426      40.61279
# 27       5417.82      16941.34   30586.338000   2738.268854    3265.81279
# 28      -2134.81      -13579.9  -23262.140725  -2634.451427       -3225.2
# 29     -55.62372   4498.917839    4358.018396       6130.21       4022.26
# 30  -1163.904417  -3713.908056   -3681.356551  -1878.374822   2497.709856
# 31  42773.548772  52238.140722  166343.899317  22425.792846  28465.346655
# 32  -43937.45319 -55952.048778 -170025.255868 -24304.167668 -25967.636798
# 33           NaN           NaN            NaN           NaN           NaN
# 34           NaN           NaN            NaN           NaN           NaN
# 35           NaN           NaN            NaN           NaN           NaN
# 36           NaN           NaN            NaN           NaN           NaN
# 37           NaN           NaN            NaN           NaN           NaN
# 38           NaN           NaN            NaN           NaN           NaN
# 39           NaN           NaN            NaN           NaN           NaN
# 40           NaN           NaN            NaN           NaN           NaN
# 41           NaN           NaN            NaN           NaN           NaN
#
#     Unnamed: 138  Unnamed: 139   Unnamed: 140
# 0            NaN           NaN            NaN
# 1            NaN           NaN            NaN
# 2            NaN           NaN            NaN
# 3        Q3 2021       Q4 2021    2021.000000
# 4    4218.278419  14673.099443   25362.808233
# 5    20264.09096  27106.148991   65188.927114
# 6              0             0       0.000000
# 7              0             0       0.000000
# 8       434.6187    261.048644     603.946119
# 9      53.346742     -4.497766     -94.464390
# 10     356.53265    207.718873     998.014652
# 11     24.739308     57.827537    -299.604143
# 12   19829.47226  26845.100347   64584.980995
# 13     4945.8397    20414.7919   28528.255400
# 14     5518.1492    31577.1125   40926.861200
# 15     -572.3095   -11162.3206  -12398.605800
# 16      14044.52      13064.98   37814.177807
# 17     839.11256  -6634.671553   -1757.452212
# 18  29772.936601  37593.734208  127963.439609
# 19 -28933.824041 -44228.405761 -129720.891821
# 20  16045.812541  12433.049548   39826.118881
# 21    1396.47607   1214.914733    3042.412344
# 22    110.987658    297.005218     243.453351
# 23    749.301808    760.577946    2566.190813
# 24    536.186604    157.331569     232.768180
# 25  14649.336471  11218.134815   36783.706537
# 26        -87.02        883.11     940.520217
# 27       4110.83       5461.93   15576.841644
# 28      -4197.85      -4578.82  -14636.321427
# 29      12877.76      12180.22   35210.450000
# 30   1858.596471  -1845.195185     632.736320
# 31  30566.458682  48923.898997  130381.497180
# 32 -28707.862211 -50769.094182 -129748.760859
# 33           NaN           NaN            NaN
# 34           NaN           NaN            NaN
# 35           NaN           NaN            NaN
# 36           NaN           NaN            NaN
# 37           NaN           NaN            NaN
# 38           NaN           NaN            NaN
# 39           NaN           NaN            NaN
# 40           NaN           NaN            NaN
# 41           NaN           NaN            NaN
#
# [42 rows x 141 columns]

# %%
df = pd.DataFrame()#columns = ['Date', 'DI'])
df["Date"] = df1.iloc[3]
df["DI"] = df1.iloc[4]

# %%
df = df.reset_index(drop=True)
df.head(10)
# Out:
#       Date                 DI
# 0      NaN  Direct investment
# 1  Q1 1994          -66.95455
# 2  Q2 1994           -50.6787
# 3  Q3 1994           -51.5994
# 4  Q4 1994          -209.3712
# 5     1994         -378.60385
# 6  Q1 1995          -69.52675
# 7  Q2 1995          -113.6062
# 8  Q3 1995         -456.94645
# 9  Q4 1995          -819.8606

# %%
df.index[0::5]
# Out:
# RangeIndex(start=0, stop=141, step=5)

# %%
df.drop(df.index[0::5], axis=0, inplace=True)

# %%
df
# Out:
#         Date            DI
# 1    Q1 1994     -66.95455
# 2    Q2 1994      -50.6787
# 3    Q3 1994      -51.5994
# 4    Q4 1994     -209.3712
# 6    Q1 1995     -69.52675
# ..       ...           ...
# 134  Q4 2020   -979.762267
# 136  Q1 2021     3182.8281
# 137  Q2 2021   3288.602271
# 138  Q3 2021   4218.278419
# 139  Q4 2021  14673.099443
#
# [112 rows x 2 columns]

# %%
df['Datetime'] = pd.date_range(start='01-01-1994', periods=len(df), freq="Q")
df.set_index("Datetime", inplace = True)

# %%
df["DI"].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
df.to_csv("test.csv")

# %%
from datetime import datetime

def diff_month(d1, d2):
    return (d2.year - d1.year) * 365 + d2.day - d1.day

diff_month(datetime(2009,6,30),datetime(2016,1,1))

# %%
# correlation to Captital outflow (BOP) to other indicators such as interest rates & exchange rates

# %%
# correlation of Captial outflow to GDP to Debt Ratio (more macro economic long term )
