# %%
import quandl
import matplotlib.pyplot as plt
import pandas as pd

# %%
quandl.ApiConfig.api_key = 'XYZ'

# %%
df = pd.DataFrame(quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', paginate=True))
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# <ipython-input-83-57b3b9bd7a42> in <module>
# ----> 1 df = pd.DataFrame(quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', paginate=True))
#
# ~/anaconda3/lib/python3.8/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      25
#      26         if page_count >= ApiConfig.page_limit:
# ---> 27             raise LimitExceededError(
#      28                 Message.WARN_DATA_LIMIT_EXCEEDED % (datatable_code,
#      29                                                     ApiConfig.api_key
#
# ...

# %%
df = df.iloc[::-1]

# %%
df = df.drop(['indicator_id', 'region_id'], axis=1)

# %%
df = df.set_index('date')

# %%
df.head()
# Out:
#               value
# date
# 1996-01-31  94782.0
# 1996-02-29  94376.0
# 1996-03-31  94398.0
# 1996-04-30  94364.0
# 1996-05-31  94870.0

# %%
df.tail()
# Out:
#                value
# date
# 2020-08-31  209130.0
# 2020-09-30  216819.0
# 2020-10-31  221488.0
# 2020-11-30  224551.0
# 2020-12-31  227584.0

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df = pd.DataFrame(quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', region_id='884'))

# %%
df = df.iloc[::-1]

# %%
df = df.drop(['indicator_id', 'region_id'], axis=1)

# %%
df = df.set_index('date')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='date'>
