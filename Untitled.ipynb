# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/home/ubuntu/Desktop/katya.csv')

# %%
# Out:
# /home/ubuntu/Desktop/Quantitative-Finance

# %%
df.head(2)
# Out:
#   Unnamed: 0          1                      2                        3  \
# 0        NaN  Я спокоен  Мне ничто не угрожает  Я нахожусь в напряжении
# 1    Кукмебр          3                      1                        1
#
#                     4                         5            6  \
# 0  Я внутренне скован  Я чувствую себя свободно  Я расстроен
# 1                   2                         2            1
#
#                                 7                        8             9  ...  \
# 0  Меня волнуют возможные неудачи  Я ощущаю душевный покой  Я встревожен  ...
# 1                               3                        3             1  ...
#
#           16          17                                    18            19  \
# 0  Я доволен  Я озабочен  Я слишком возбужден и мне не по себе  Мне радостно
# 1          3           1                                     1             4
#
#             20 Unnamed: 21    ∑1    ∑2 Unnamed: 24 Unnamed: 25
# ...

# %%
df
# Out:
#          Unnamed: 0          1                      2  \
# 0               NaN  Я спокоен  Мне ничто не угрожает
# 1           Кукмебр          3                      1
# 2    Buffett_Stonks          1                      2
# 3          mmicammi          3                      1
# 4          Вовчикус          2                      1
# ..              ...        ...                    ...
# 115             ***          2                      2
# 116              Ks          3                      1
# 117               М          4                      2
# 118         amadin1          1                      2
# 119             Аня          1                      2
#
#                            3                   4                         5  \
# 0    Я нахожусь в напряжении  Я внутренне скован  Я чувствую себя свободно
# 1                          1                   2                         2
# 2                          1                   2                         3
# ...

# %%
corr = df.corr()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Greens",annot=True)
# Out:
# <AxesSubplot:>
